# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from utils import data_loader
from utils.viewer import show_batch
from mnist_classifier import NeuralModel, train_model, test_model
from classifier_attacks import test_attack
import matplotlib.pyplot as plt

# %%
train_set, test_set = data_loader.get_data()
use_cuda = True
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

batch_size = 512
train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size)

# %%
model = NeuralModel()

# %%
trained_model = train_model(model, train_loader, epochs =10)
# Out:
# started training ...
# the loss after processing this batch is:  2.3372018337249756
# the loss after processing this batch is:  2.3123111724853516
# the loss after processing this batch is:  2.2923953533172607
# the loss after processing this batch is:  2.280707597732544
# the loss after processing this batch is:  2.2683937549591064
# the loss after processing this batch is:  2.2526211738586426
# the loss after processing this batch is:  2.2340281009674072
# the loss after processing this batch is:  2.2257449626922607
# the loss after processing this batch is:  2.203766345977783
# the loss after processing this batch is:  2.2038886547088623
# the loss after processing this batch is:  2.1875176429748535
# the loss after processing this batch is:  2.1845247745513916
# the loss after processing this batch is:  2.1632494926452637
# the loss after processing this batch is:  2.160036325454712
# the loss after processing this batch is:  2.1574926376342773
# the loss after processing this batch is:  2.12638258934021
# the loss after processing this batch is:  2.1280369758605957
# the loss after processing this batch is:  2.1004645824432373
# the loss after processing this batch is:  2.0844430923461914
# the loss after processing this batch is:  2.074451208114624
# the loss after processing this batch is:  2.047689199447632
# the loss after processing this batch is:  2.0289011001586914
# the loss after processing this batch is:  2.0111513137817383
# the loss after processing this batch is:  2.0103836059570312
# the loss after processing this batch is:  1.9970370531082153
# the loss after processing this batch is:  1.9967316389083862
# the loss after processing this batch is:  1.957507610321045
# the loss after processing this batch is:  1.9785797595977783
# the loss after processing this batch is:  1.951836347579956
# the loss after processing this batch is:  1.8960411548614502
# the loss after processing this batch is:  1.8938356637954712
# the loss after processing this batch is:  1.8635600805282593
# the loss after processing this batch is:  1.852880835533142
# the loss after processing this batch is:  1.8264565467834473
# the loss after processing this batch is:  1.8499324321746826
# the loss after processing this batch is:  1.7674669027328491
# the loss after processing this batch is:  1.7711467742919922
# the loss after processing this batch is:  1.7451952695846558
# the loss after processing this batch is:  1.7302961349487305
# the loss after processing this batch is:  1.7033647298812866
# the loss after processing this batch is:  1.7123550176620483
# the loss after processing this batch is:  1.6595206260681152
# the loss after processing this batch is:  1.6251088380813599
# the loss after processing this batch is:  1.688766598701477
# the loss after processing this batch is:  1.6071627140045166
# the loss after processing this batch is:  1.5738162994384766
# the loss after processing this batch is:  1.613675832748413
# the loss after processing this batch is:  1.5337926149368286
# the loss after processing this batch is:  1.5433032512664795
# the loss after processing this batch is:  1.4661060571670532
# the loss after processing this batch is:  1.419761300086975
# the loss after processing this batch is:  1.4659907817840576
# the loss after processing this batch is:  1.4586435556411743
# the loss after processing this batch is:  1.4194029569625854
# the loss after processing this batch is:  1.3506858348846436
# the loss after processing this batch is:  1.3651347160339355
# the loss after processing this batch is:  1.3668603897094727
# the loss after processing this batch is:  1.3077733516693115
# the loss after processing this batch is:  1.3810815811157227
# the loss after processing this batch is:  1.2970912456512451
# the loss after processing this batch is:  1.2849847078323364
# the loss after processing this batch is:  1.2827672958374023
# the loss after processing this batch is:  1.2469068765640259
# the loss after processing this batch is:  1.2553117275238037
# the loss after processing this batch is:  1.1959418058395386
# the loss after processing this batch is:  1.1147295236587524
# the loss after processing this batch is:  1.0567928552627563
# the loss after processing this batch is:  1.1453183889389038
# the loss after processing this batch is:  1.1442714929580688
# the loss after processing this batch is:  1.076838493347168
# the loss after processing this batch is:  1.0581399202346802
# the loss after processing this batch is:  1.0429556369781494
# the loss after processing this batch is:  1.0543028116226196
# the loss after processing this batch is:  0.9968589544296265
# the loss after processing this batch is:  0.9364873170852661
# the loss after processing this batch is:  0.8832502961158752
# the loss after processing this batch is:  0.8958333134651184
# the loss after processing this batch is:  0.9731401205062866
# the loss after processing this batch is:  0.8436552882194519
# the loss after processing this batch is:  0.8228961229324341
# the loss after processing this batch is:  0.9065128564834595
# the loss after processing this batch is:  0.8032897114753723
# the loss after processing this batch is:  0.8767704367637634
# the loss after processing this batch is:  0.8026555180549622
# the loss after processing this batch is:  0.7764931321144104
# the loss after processing this batch is:  0.7601346373558044
# the loss after processing this batch is:  0.7687987685203552
# the loss after processing this batch is:  0.6994997262954712
# the loss after processing this batch is:  0.6947804689407349
# the loss after processing this batch is:  0.7213890552520752
# the loss after processing this batch is:  0.7163246870040894
# the loss after processing this batch is:  0.6512887477874756
# the loss after processing this batch is:  0.6687946915626526
# the loss after processing this batch is:  0.6319887638092041
# the loss after processing this batch is:  0.5787772536277771
# the loss after processing this batch is:  0.6153319478034973
# the loss after processing this batch is:  0.6340568661689758
# the loss after processing this batch is:  0.6036977767944336
# the loss after processing this batch is:  0.5969188213348389
# the loss after processing this batch is:  0.5614827871322632
# the loss after processing this batch is:  0.5312541127204895
# the loss after processing this batch is:  0.5686377286911011
# the loss after processing this batch is:  0.4652853310108185
# the loss after processing this batch is:  0.539340078830719
# the loss after processing this batch is:  0.47514545917510986
# the loss after processing this batch is:  0.4498395025730133
# the loss after processing this batch is:  0.43765392899513245
# the loss after processing this batch is:  0.4482765793800354
# the loss after processing this batch is:  0.42450761795043945
# the loss after processing this batch is:  0.43116703629493713
# the loss after processing this batch is:  0.4026319086551666
# the loss after processing this batch is:  0.4170251786708832
# the loss after processing this batch is:  0.4172637462615967
# the loss after processing this batch is:  0.350044310092926
# the loss after processing this batch is:  0.3106755316257477
# the loss after processing this batch is:  0.33348914980888367
# the loss after processing this batch is:  0.37752455472946167
# the loss after processing this batch is:  0.4272526502609253
# the loss after processing this batch is:  0.37304461002349854
# the loss after processing this batch is:  0.37361106276512146
# the loss after processing this batch is:  0.42258644104003906
# the loss after processing this batch is:  0.30886518955230713
# the loss after processing this batch is:  0.3309139609336853
# the loss after processing this batch is:  0.339908629655838
# the loss after processing this batch is:  0.3086102306842804
# the loss after processing this batch is:  0.3451635241508484
# the loss after processing this batch is:  0.34777992963790894
# the loss after processing this batch is:  0.37439629435539246
# the loss after processing this batch is:  0.36504876613616943
# the loss after processing this batch is:  0.35471493005752563
# the loss after processing this batch is:  0.3083571791648865
# the loss after processing this batch is:  0.3564950227737427
# the loss after processing this batch is:  0.32612231373786926
# the loss after processing this batch is:  0.3105362355709076
# the loss after processing this batch is:  0.38035568594932556
# the loss after processing this batch is:  0.34097549319267273
# the loss after processing this batch is:  0.32844340801239014
# the loss after processing this batch is:  0.2897290289402008
# the loss after processing this batch is:  0.25072550773620605
# the loss after processing this batch is:  0.28044575452804565
# the loss after processing this batch is:  0.2850690186023712
# the loss after processing this batch is:  0.2846626937389374
# the loss after processing this batch is:  0.3234800398349762
# the loss after processing this batch is:  0.3224123418331146
# the loss after processing this batch is:  0.2543838918209076
# the loss after processing this batch is:  0.324651300907135
# the loss after processing this batch is:  0.3563988208770752
# the loss after processing this batch is:  0.25054624676704407
# the loss after processing this batch is:  0.27693766355514526
# the loss after processing this batch is:  0.25418710708618164
# the loss after processing this batch is:  0.23504193127155304
# the loss after processing this batch is:  0.2855149507522583
# the loss after processing this batch is:  0.33176642656326294
# the loss after processing this batch is:  0.20931662619113922
# the loss after processing this batch is:  0.2156950831413269
# the loss after processing this batch is:  0.2357904314994812
# the loss after processing this batch is:  0.21133317053318024
# the loss after processing this batch is:  0.24374166131019592
# the loss after processing this batch is:  0.2720479369163513
# the loss after processing this batch is:  0.23195317387580872
# the loss after processing this batch is:  0.17379753291606903
# the loss after processing this batch is:  0.23575429618358612
# the loss after processing this batch is:  0.2322523593902588
# the loss after processing this batch is:  0.19079461693763733
# the loss after processing this batch is:  0.24086996912956238
# the loss after processing this batch is:  0.2211022824048996
# the loss after processing this batch is:  0.2734048068523407
# the loss after processing this batch is:  0.1852818876504898
# the loss after processing this batch is:  0.20465099811553955
# the loss after processing this batch is:  0.24706308543682098
# the loss after processing this batch is:  0.26038306951522827
# the loss after processing this batch is:  0.2563978135585785
# the loss after processing this batch is:  0.17184825241565704
# the loss after processing this batch is:  0.2202165424823761
# the loss after processing this batch is:  0.20322953164577484
# the loss after processing this batch is:  0.20149612426757812
# the loss after processing this batch is:  0.26798808574676514
# the loss after processing this batch is:  0.21361467242240906
# the loss after processing this batch is:  0.22936826944351196
# the loss after processing this batch is:  0.26225167512893677
# the loss after processing this batch is:  0.21959127485752106
# the loss after processing this batch is:  0.2547042965888977
# the loss after processing this batch is:  0.2078971415758133
# the loss after processing this batch is:  0.17235945165157318
# the loss after processing this batch is:  0.13753192126750946
# the loss after processing this batch is:  0.22222749888896942
# the loss after processing this batch is:  0.17664667963981628
# the loss after processing this batch is:  0.1660647839307785
# the loss after processing this batch is:  0.1963416039943695
# the loss after processing this batch is:  0.16652435064315796
# the loss after processing this batch is:  0.19770574569702148
# the loss after processing this batch is:  0.20657409727573395
# the loss after processing this batch is:  0.15731599926948547
# the loss after processing this batch is:  0.15761710703372955
# the loss after processing this batch is:  0.17678025364875793
# the loss after processing this batch is:  0.20287227630615234
# the loss after processing this batch is:  0.14677275717258453
# the loss after processing this batch is:  0.15170477330684662
# the loss after processing this batch is:  0.23816612362861633
# the loss after processing this batch is:  0.15382491052150726
# the loss after processing this batch is:  0.1955914944410324
# the loss after processing this batch is:  0.18736863136291504
# the loss after processing this batch is:  0.1519145518541336
# the loss after processing this batch is:  0.16077350080013275
# the loss after processing this batch is:  0.15879295766353607
# the loss after processing this batch is:  0.14731891453266144
# the loss after processing this batch is:  0.16186892986297607
# the loss after processing this batch is:  0.19640560448169708
# the loss after processing this batch is:  0.19489844143390656
# the loss after processing this batch is:  0.16834992170333862
# the loss after processing this batch is:  0.18056707084178925
# the loss after processing this batch is:  0.14444321393966675
# the loss after processing this batch is:  0.12225635349750519
# the loss after processing this batch is:  0.18291212618350983
# the loss after processing this batch is:  0.189258873462677
# the loss after processing this batch is:  0.14628255367279053
# the loss after processing this batch is:  0.2028800994157791
# the loss after processing this batch is:  0.1560918092727661
# the loss after processing this batch is:  0.13672426342964172
# the loss after processing this batch is:  0.1872238963842392
# the loss after processing this batch is:  0.12015959620475769
# the loss after processing this batch is:  0.1945459246635437
# the loss after processing this batch is:  0.13534925878047943
# the loss after processing this batch is:  0.133279487490654
# the loss after processing this batch is:  0.1190279871225357
# the loss after processing this batch is:  0.1361425518989563
# the loss after processing this batch is:  0.12680448591709137
# the loss after processing this batch is:  0.12790387868881226
# the loss after processing this batch is:  0.1325719803571701
# the loss after processing this batch is:  0.12022824585437775
# the loss after processing this batch is:  0.13215544819831848
# the loss after processing this batch is:  0.08025936037302017
# the loss after processing this batch is:  0.07089484483003616
# the loss after processing this batch is:  0.09045707434415817
# the loss after processing this batch is:  0.16391412913799286
# the loss after processing this batch is:  0.19910548627376556
# the loss after processing this batch is:  0.1505681872367859
# the loss after processing this batch is:  0.1282043755054474
# the loss after processing this batch is:  0.1525350958108902
# the loss after processing this batch is:  0.11185608059167862
# the loss after processing this batch is:  0.1077289804816246
# the loss after processing this batch is:  0.14849479496479034
# the loss after processing this batch is:  0.11062606424093246
# the loss after processing this batch is:  0.15142858028411865
# the loss after processing this batch is:  0.14777906239032745
# the loss after processing this batch is:  0.1569715440273285
# the loss after processing this batch is:  0.15961584448814392
# the loss after processing this batch is:  0.16306155920028687
# the loss after processing this batch is:  0.12350673228502274
# the loss after processing this batch is:  0.15868224203586578
# the loss after processing this batch is:  0.1417081654071808
# the loss after processing this batch is:  0.13214433193206787
# the loss after processing this batch is:  0.16511285305023193
# the loss after processing this batch is:  0.16336175799369812
# the loss after processing this batch is:  0.18108390271663666
# the loss after processing this batch is:  0.13055004179477692
# the loss after processing this batch is:  0.10065457969903946
# the loss after processing this batch is:  0.11855393648147583
# the loss after processing this batch is:  0.11759805679321289
# the loss after processing this batch is:  0.11557133495807648
# the loss after processing this batch is:  0.15627190470695496
# the loss after processing this batch is:  0.15655943751335144
# the loss after processing this batch is:  0.11839637160301208
# the loss after processing this batch is:  0.141912579536438
# the loss after processing this batch is:  0.17079249024391174
# the loss after processing this batch is:  0.10464831441640854
# the loss after processing this batch is:  0.13176193833351135
# the loss after processing this batch is:  0.12024694681167603
# the loss after processing this batch is:  0.11173885315656662
# the loss after processing this batch is:  0.1429601013660431
# the loss after processing this batch is:  0.1721624881029129
# the loss after processing this batch is:  0.09977913647890091
# the loss after processing this batch is:  0.09507525712251663
# the loss after processing this batch is:  0.12274494767189026
# the loss after processing this batch is:  0.10887039452791214
# the loss after processing this batch is:  0.1340479850769043
# the loss after processing this batch is:  0.14669093489646912
# the loss after processing this batch is:  0.09905613958835602
# the loss after processing this batch is:  0.07218106836080551
# the loss after processing this batch is:  0.1162741407752037
# the loss after processing this batch is:  0.11285746097564697
# the loss after processing this batch is:  0.08391967415809631
# the loss after processing this batch is:  0.1286003589630127
# the loss after processing this batch is:  0.10111009329557419
# the loss after processing this batch is:  0.16837245225906372
# the loss after processing this batch is:  0.1024240180850029
# the loss after processing this batch is:  0.10893524438142776
# the loss after processing this batch is:  0.1442646086215973
# the loss after processing this batch is:  0.17249922454357147
# the loss after processing this batch is:  0.15020719170570374
# the loss after processing this batch is:  0.08812443912029266
# the loss after processing this batch is:  0.12804079055786133
# the loss after processing this batch is:  0.11343690007925034
# the loss after processing this batch is:  0.10546215623617172
# the loss after processing this batch is:  0.12941965460777283
# the loss after processing this batch is:  0.10820482671260834
# the loss after processing this batch is:  0.13512861728668213
# the loss after processing this batch is:  0.15631495416164398
# the loss after processing this batch is:  0.1191139966249466
# the loss after processing this batch is:  0.14510394632816315
# the loss after processing this batch is:  0.11734678596258163
# the loss after processing this batch is:  0.10847465693950653
# the loss after processing this batch is:  0.07115966826677322
# the loss after processing this batch is:  0.12686504423618317
# the loss after processing this batch is:  0.10163041949272156
# the loss after processing this batch is:  0.09075133502483368
# the loss after processing this batch is:  0.10064106434583664
# the loss after processing this batch is:  0.08542655408382416
# the loss after processing this batch is:  0.11823632568120956
# the loss after processing this batch is:  0.12396550923585892
# the loss after processing this batch is:  0.08817065507173538
# the loss after processing this batch is:  0.09010331332683563
# the loss after processing this batch is:  0.11339493095874786
# the loss after processing this batch is:  0.12448698282241821
# the loss after processing this batch is:  0.08523818850517273
# the loss after processing this batch is:  0.0953732579946518
# the loss after processing this batch is:  0.150519460439682
# the loss after processing this batch is:  0.09851221740245819
# the loss after processing this batch is:  0.12107885628938675
# the loss after processing this batch is:  0.11386743187904358
# the loss after processing this batch is:  0.0865236446261406
# the loss after processing this batch is:  0.10164824873209
# the loss after processing this batch is:  0.09869035333395004
# the loss after processing this batch is:  0.08965010195970535
# the loss after processing this batch is:  0.10130314528942108
# the loss after processing this batch is:  0.12926551699638367
# the loss after processing this batch is:  0.12324761599302292
# the loss after processing this batch is:  0.11151721328496933
# the loss after processing this batch is:  0.12418726086616516
# the loss after processing this batch is:  0.09313565492630005
# the loss after processing this batch is:  0.07392486929893494
# the loss after processing this batch is:  0.13220559060573578
# the loss after processing this batch is:  0.13184615969657898
# the loss after processing this batch is:  0.09018702805042267
# the loss after processing this batch is:  0.13859833776950836
# the loss after processing this batch is:  0.09515482187271118
# the loss after processing this batch is:  0.08933743834495544
# the loss after processing this batch is:  0.13146495819091797
# the loss after processing this batch is:  0.07221777737140656
# the loss after processing this batch is:  0.14701390266418457
# the loss after processing this batch is:  0.08965739607810974
# the loss after processing this batch is:  0.08600389957427979
# the loss after processing this batch is:  0.07634682953357697
# the loss after processing this batch is:  0.08881876617670059
# the loss after processing this batch is:  0.0900755524635315
# the loss after processing this batch is:  0.08397608995437622
# the loss after processing this batch is:  0.09029915928840637
# the loss after processing this batch is:  0.07117841392755508
# the loss after processing this batch is:  0.0830550268292427
# the loss after processing this batch is:  0.04391312226653099
# the loss after processing this batch is:  0.03990279510617256
# the loss after processing this batch is:  0.056636400520801544
# the loss after processing this batch is:  0.1315968632698059
# the loss after processing this batch is:  0.1664598435163498
# the loss after processing this batch is:  0.1132325679063797
# the loss after processing this batch is:  0.0850749984383583
# the loss after processing this batch is:  0.10707557946443558
# the loss after processing this batch is:  0.08109619468450546
# the loss after processing this batch is:  0.06605780869722366
# the loss after processing this batch is:  0.10633020102977753
# the loss after processing this batch is:  0.07163374871015549
# the loss after processing this batch is:  0.10538098216056824
# the loss after processing this batch is:  0.11200497299432755
# the loss after processing this batch is:  0.10709602385759354
# the loss after processing this batch is:  0.10877684503793716
# the loss after processing this batch is:  0.1218029260635376
# the loss after processing this batch is:  0.08158920705318451
# the loss after processing this batch is:  0.11154815554618835
# the loss after processing this batch is:  0.10055749118328094
# the loss after processing this batch is:  0.09432296454906464
# the loss after processing this batch is:  0.11383188515901566
# the loss after processing this batch is:  0.11477698385715485
# the loss after processing this batch is:  0.13792890310287476
# the loss after processing this batch is:  0.09049428254365921
# the loss after processing this batch is:  0.06992286443710327
# the loss after processing this batch is:  0.08588200807571411
# the loss after processing this batch is:  0.0788993090391159
# the loss after processing this batch is:  0.07728105783462524
# the loss after processing this batch is:  0.10526614636182785
# the loss after processing this batch is:  0.10685358196496964
# the loss after processing this batch is:  0.07685211300849915
# the loss after processing this batch is:  0.09305087476968765
# the loss after processing this batch is:  0.11527668684720993
# the loss after processing this batch is:  0.06529736518859863
# the loss after processing this batch is:  0.08961907029151917
# the loss after processing this batch is:  0.08485254645347595
# the loss after processing this batch is:  0.0824597105383873
# the loss after processing this batch is:  0.10343147069215775
# the loss after processing this batch is:  0.12218128144741058
# the loss after processing this batch is:  0.07565275579690933
# the loss after processing this batch is:  0.06090043485164642
# the loss after processing this batch is:  0.08843942731618881
# the loss after processing this batch is:  0.08212120831012726
# the loss after processing this batch is:  0.09770416468381882
# the loss after processing this batch is:  0.11256106197834015
# the loss after processing this batch is:  0.06499364972114563
# the loss after processing this batch is:  0.04462417587637901
# the loss after processing this batch is:  0.07276729494333267
# the loss after processing this batch is:  0.07983742654323578
# the loss after processing this batch is:  0.054213300347328186
# the loss after processing this batch is:  0.09482526779174805
# the loss after processing this batch is:  0.06605648249387741
# the loss after processing this batch is:  0.13247637450695038
# the loss after processing this batch is:  0.0810997486114502
# the loss after processing this batch is:  0.08198882639408112
# the loss after processing this batch is:  0.10726984590291977
# the loss after processing this batch is:  0.1400749683380127
# the loss after processing this batch is:  0.11193318665027618
# the loss after processing this batch is:  0.05854588747024536
# the loss after processing this batch is:  0.09844769537448883
# the loss after processing this batch is:  0.08320301026105881
# the loss after processing this batch is:  0.0760824978351593
# the loss after processing this batch is:  0.08316431194543839
# the loss after processing this batch is:  0.07437556236982346
# the loss after processing this batch is:  0.09906385838985443
# the loss after processing this batch is:  0.12121575325727463
# the loss after processing this batch is:  0.08178159594535828
# the loss after processing this batch is:  0.1092573031783104
# the loss after processing this batch is:  0.08456253260374069
# the loss after processing this batch is:  0.08579646050930023
# the loss after processing this batch is:  0.04988788813352585
# the loss after processing this batch is:  0.09794355183839798
# the loss after processing this batch is:  0.07701286673545837
# the loss after processing this batch is:  0.07273735105991364
# the loss after processing this batch is:  0.06792479753494263
# the loss after processing this batch is:  0.06340400129556656
# the loss after processing this batch is:  0.09072188287973404
# the loss after processing this batch is:  0.09733511507511139
# the loss after processing this batch is:  0.06567174196243286
# the loss after processing this batch is:  0.06417353451251984
# the loss after processing this batch is:  0.08788548409938812
# the loss after processing this batch is:  0.09455796331167221
# the loss after processing this batch is:  0.06629809737205505
# the loss after processing this batch is:  0.07207867503166199
# the loss after processing this batch is:  0.11354083567857742
# the loss after processing this batch is:  0.07643789052963257
# the loss after processing this batch is:  0.09532882273197174
# the loss after processing this batch is:  0.08222436904907227
# the loss after processing this batch is:  0.06662075221538544
# the loss after processing this batch is:  0.07303555309772491
# the loss after processing this batch is:  0.07879681140184402
# the loss after processing this batch is:  0.0675295889377594
# the loss after processing this batch is:  0.07635641098022461
# the loss after processing this batch is:  0.10080555826425552
# the loss after processing this batch is:  0.09887026250362396
# the loss after processing this batch is:  0.08655661344528198
# the loss after processing this batch is:  0.10395283252000809
# the loss after processing this batch is:  0.07194110006093979
# the loss after processing this batch is:  0.053777024149894714
# the loss after processing this batch is:  0.11275583505630493
# the loss after processing this batch is:  0.10808875411748886
# the loss after processing this batch is:  0.06958890706300735
# the loss after processing this batch is:  0.10941000282764435
# the loss after processing this batch is:  0.06760570406913757
# the loss after processing this batch is:  0.07292932271957397
# the loss after processing this batch is:  0.10726139694452286
# the loss after processing this batch is:  0.05463281646370888
# the loss after processing this batch is:  0.12431120872497559
# the loss after processing this batch is:  0.07040373980998993
# the loss after processing this batch is:  0.06748732924461365
# the loss after processing this batch is:  0.06215980648994446
# the loss after processing this batch is:  0.06652113795280457
# the loss after processing this batch is:  0.06907829642295837
# the loss after processing this batch is:  0.06552378833293915
# the loss after processing this batch is:  0.07057761400938034
# the loss after processing this batch is:  0.050610389560461044
# the loss after processing this batch is:  0.06528415530920029
# the loss after processing this batch is:  0.03177277743816376
# the loss after processing this batch is:  0.027626750990748405
# the loss after processing this batch is:  0.04075072333216667
# the loss after processing this batch is:  0.11326301097869873
# the loss after processing this batch is:  0.1616770327091217
# the loss after processing this batch is:  0.09239639341831207
# the loss after processing this batch is:  0.0674963966012001
# the loss after processing this batch is:  0.0865640938282013
# the loss after processing this batch is:  0.0633733943104744
# the loss after processing this batch is:  0.05130171403288841
# the loss after processing this batch is:  0.08820971846580505
# the loss after processing this batch is:  0.055784448981285095
# the loss after processing this batch is:  0.0822933241724968
# the loss after processing this batch is:  0.08849627524614334
# the loss after processing this batch is:  0.08641669899225235
# the loss after processing this batch is:  0.08376547694206238
# the loss after processing this batch is:  0.10241410881280899
# the loss after processing this batch is:  0.06826421618461609
# the loss after processing this batch is:  0.08877002447843552
# the loss after processing this batch is:  0.08508041501045227
# the loss after processing this batch is:  0.07188452780246735
# the loss after processing this batch is:  0.0922020822763443
# the loss after processing this batch is:  0.09375293552875519
# the loss after processing this batch is:  0.11404202878475189
# the loss after processing this batch is:  0.07053795456886292
# the loss after processing this batch is:  0.05499173328280449
# the loss after processing this batch is:  0.0703301653265953
# the loss after processing this batch is:  0.05977486073970795
# the loss after processing this batch is:  0.05922798439860344
# the loss after processing this batch is:  0.08435283601284027
# the loss after processing this batch is:  0.08220835030078888
# the loss after processing this batch is:  0.05843571200966835
# the loss after processing this batch is:  0.06959563493728638
# the loss after processing this batch is:  0.08745620399713516
# the loss after processing this batch is:  0.04845784604549408
# the loss after processing this batch is:  0.06615358591079712
# the loss after processing this batch is:  0.06966638565063477
# the loss after processing this batch is:  0.0666426420211792
# the loss after processing this batch is:  0.08015882968902588
# the loss after processing this batch is:  0.0958220511674881
# the loss after processing this batch is:  0.06490452587604523
# the loss after processing this batch is:  0.04618862643837929
# the loss after processing this batch is:  0.07174665480852127
# the loss after processing this batch is:  0.0711783766746521
# the loss after processing this batch is:  0.07853835076093674
# the loss after processing this batch is:  0.09467743337154388
# the loss after processing this batch is:  0.04912896454334259
# the loss after processing this batch is:  0.03192833811044693
# the loss after processing this batch is:  0.05221214145421982
# the loss after processing this batch is:  0.06461749225854874
# the loss after processing this batch is:  0.041742973029613495
# the loss after processing this batch is:  0.07515799254179001
# the loss after processing this batch is:  0.04967062175273895
# the loss after processing this batch is:  0.11199174076318741
# the loss after processing this batch is:  0.06677112728357315
# the loss after processing this batch is:  0.06562592834234238
# the loss after processing this batch is:  0.08786294609308243
# the loss after processing this batch is:  0.11825781315565109
# the loss after processing this batch is:  0.08925427496433258
# the loss after processing this batch is:  0.04235212877392769
# the loss after processing this batch is:  0.08283817023038864
# the loss after processing this batch is:  0.06836801022291183
# the loss after processing this batch is:  0.059742968529462814
# the loss after processing this batch is:  0.06355760246515274
# the loss after processing this batch is:  0.05610939487814903
# the loss after processing this batch is:  0.07823324203491211
# the loss after processing this batch is:  0.10281269252300262
# the loss after processing this batch is:  0.061833590269088745
# the loss after processing this batch is:  0.09231510758399963
# the loss after processing this batch is:  0.06452655792236328
# the loss after processing this batch is:  0.07177228480577469
# the loss after processing this batch is:  0.039187654852867126
# the loss after processing this batch is:  0.0775836929678917
# the loss after processing this batch is:  0.06819843500852585
# the loss after processing this batch is:  0.06418601423501968
# the loss after processing this batch is:  0.05182713270187378
# the loss after processing this batch is:  0.05404342710971832
# the loss after processing this batch is:  0.07294003665447235
# the loss after processing this batch is:  0.07832679897546768
# the loss after processing this batch is:  0.05158597603440285
# the loss after processing this batch is:  0.05182815343141556
# the loss after processing this batch is:  0.07426171749830246
# the loss after processing this batch is:  0.07429272681474686
# the loss after processing this batch is:  0.0562046617269516
# the loss after processing this batch is:  0.0598159022629261
# the loss after processing this batch is:  0.09023765474557877
# the loss after processing this batch is:  0.06379174441099167
# the loss after processing this batch is:  0.07599599659442902
# the loss after processing this batch is:  0.06508420407772064
# the loss after processing this batch is:  0.05782629922032356
# the loss after processing this batch is:  0.0582953542470932
# the loss after processing this batch is:  0.06707292795181274
# the loss after processing this batch is:  0.05711799114942551
# the loss after processing this batch is:  0.05938437953591347
# the loss after processing this batch is:  0.08903000503778458
# the loss after processing this batch is:  0.08544163405895233
# the loss after processing this batch is:  0.07280819863080978
# the loss after processing this batch is:  0.09027965366840363
# the loss after processing this batch is:  0.0580456405878067
# the loss after processing this batch is:  0.0414593331515789
# the loss after processing this batch is:  0.10000164061784744
# the loss after processing this batch is:  0.09289844334125519
# the loss after processing this batch is:  0.060555655509233475
# the loss after processing this batch is:  0.09312193840742111
# the loss after processing this batch is:  0.05334256589412689
# the loss after processing this batch is:  0.06281216442584991
# the loss after processing this batch is:  0.0905684381723404
# the loss after processing this batch is:  0.04417755454778671
# the loss after processing this batch is:  0.10716238617897034
# the loss after processing this batch is:  0.05733942613005638
# the loss after processing this batch is:  0.054333996027708054
# the loss after processing this batch is:  0.052631624042987823
# the loss after processing this batch is:  0.0540366992354393
# the loss after processing this batch is:  0.05871373414993286
# the loss after processing this batch is:  0.056955136358737946
# the loss after processing this batch is:  0.06107011437416077
# the loss after processing this batch is:  0.03807169944047928
# the loss after processing this batch is:  0.05373004451394081
# the loss after processing this batch is:  0.02467772550880909
# the loss after processing this batch is:  0.021506693214178085
# the loss after processing this batch is:  0.03125355392694473
# the loss after processing this batch is:  0.09861407428979874
# the loss after processing this batch is:  0.15737594664096832
# the loss after processing this batch is:  0.07718488574028015
# the loss after processing this batch is:  0.05788425728678703
# the loss after processing this batch is:  0.07445321977138519
# the loss after processing this batch is:  0.05224413424730301
# the loss after processing this batch is:  0.043156698346138
# the loss after processing this batch is:  0.07515157759189606
# the loss after processing this batch is:  0.04658319056034088
# the loss after processing this batch is:  0.06620194017887115
# the loss after processing this batch is:  0.07359054684638977
# the loss after processing this batch is:  0.07398896664381027
# the loss after processing this batch is:  0.06657171249389648
# the loss after processing this batch is:  0.08934284001588821
# the loss after processing this batch is:  0.060827936977148056
# the loss after processing this batch is:  0.07427383959293365
# the loss after processing this batch is:  0.07536081969738007
# the loss after processing this batch is:  0.056044939905405045
# the loss after processing this batch is:  0.07752154767513275
# the loss after processing this batch is:  0.08021683245897293
# the loss after processing this batch is:  0.09568903595209122
# the loss after processing this batch is:  0.05708243325352669
# the loss after processing this batch is:  0.04678545892238617
# the loss after processing this batch is:  0.060961563140153885
# the loss after processing this batch is:  0.04959879815578461
# the loss after processing this batch is:  0.051821671426296234
# the loss after processing this batch is:  0.07023462653160095
# the loss after processing this batch is:  0.06993632763624191
# the loss after processing this batch is:  0.04540988430380821
# the loss after processing this batch is:  0.05668944865465164
# the loss after processing this batch is:  0.07138405740261078
# the loss after processing this batch is:  0.03828231617808342
# the loss after processing this batch is:  0.0541512630879879
# the loss after processing this batch is:  0.05995946377515793
# the loss after processing this batch is:  0.057799145579338074
# the loss after processing this batch is:  0.06442703306674957
# the loss after processing this batch is:  0.07827921956777573
# the loss after processing this batch is:  0.05696820095181465
# the loss after processing this batch is:  0.03859579190611839
# the loss after processing this batch is:  0.05985594540834427
# the loss after processing this batch is:  0.06115061044692993
# the loss after processing this batch is:  0.06504657864570618
# the loss after processing this batch is:  0.08091917634010315
# the loss after processing this batch is:  0.03783468157052994
# the loss after processing this batch is:  0.02507457509636879
# the loss after processing this batch is:  0.040275201201438904
# the loss after processing this batch is:  0.05349895730614662
# the loss after processing this batch is:  0.034543488174676895
# the loss after processing this batch is:  0.06345951557159424
# the loss after processing this batch is:  0.039029210805892944
# the loss after processing this batch is:  0.10019463300704956
# the loss after processing this batch is:  0.05622033029794693
# the loss after processing this batch is:  0.054042089730501175
# the loss after processing this batch is:  0.07632540911436081
# the loss after processing this batch is:  0.10207901895046234
# the loss after processing this batch is:  0.07247243821620941
# the loss after processing this batch is:  0.034393321722745895
# the loss after processing this batch is:  0.07010307908058167
# the loss after processing this batch is:  0.05635068565607071
# the loss after processing this batch is:  0.048025213181972504
# the loss after processing this batch is:  0.05205962434411049
# the loss after processing this batch is:  0.04265664145350456
# the loss after processing this batch is:  0.06502640247344971
# the loss after processing this batch is:  0.08836397528648376
# the loss after processing this batch is:  0.04892626404762268
# the loss after processing this batch is:  0.08211033791303635
# the loss after processing this batch is:  0.0519171804189682
# the loss after processing this batch is:  0.06328576803207397
# the loss after processing this batch is:  0.03373880311846733
# the loss after processing this batch is:  0.06346482783555984
# the loss after processing this batch is:  0.06114738807082176
# the loss after processing this batch is:  0.05543605610728264
# the loss after processing this batch is:  0.04245913773775101
# the loss after processing this batch is:  0.0479717031121254
# the loss after processing this batch is:  0.060701798647642136
# the loss after processing this batch is:  0.06748182326555252
# the loss after processing this batch is:  0.040883082896471024
# the loss after processing this batch is:  0.0427214615046978
# the loss after processing this batch is:  0.06512201577425003
# the loss after processing this batch is:  0.06063602492213249
# the loss after processing this batch is:  0.04896992817521095
# the loss after processing this batch is:  0.050713829696178436
# the loss after processing this batch is:  0.07472843676805496
# the loss after processing this batch is:  0.05434444919228554
# the loss after processing this batch is:  0.06489401310682297
# the loss after processing this batch is:  0.05724087357521057
# the loss after processing this batch is:  0.05020616203546524
# the loss after processing this batch is:  0.04759428650140762
# the loss after processing this batch is:  0.05753409117460251
# the loss after processing this batch is:  0.05024711787700653
# the loss after processing this batch is:  0.04734419286251068
# the loss after processing this batch is:  0.0797235369682312
# the loss after processing this batch is:  0.07396579533815384
# the loss after processing this batch is:  0.06595370918512344
# the loss after processing this batch is:  0.07874421775341034
# the loss after processing this batch is:  0.048336368054151535
# the loss after processing this batch is:  0.03365612030029297
# the loss after processing this batch is:  0.0890112817287445
# the loss after processing this batch is:  0.07879313826560974
# the loss after processing this batch is:  0.052129242569208145
# the loss after processing this batch is:  0.08359646052122116
# the loss after processing this batch is:  0.04577971622347832
# the loss after processing this batch is:  0.05501966178417206
# the loss after processing this batch is:  0.07899531722068787
# the loss after processing this batch is:  0.03671612590551376
# the loss after processing this batch is:  0.09074492752552032
# the loss after processing this batch is:  0.049370840191841125
# the loss after processing this batch is:  0.044372864067554474
# the loss after processing this batch is:  0.045127712190151215
# the loss after processing this batch is:  0.04559391736984253
# the loss after processing this batch is:  0.053175486624240875
# the loss after processing this batch is:  0.05150055140256882
# the loss after processing this batch is:  0.05571359768509865
# the loss after processing this batch is:  0.030966684222221375
# the loss after processing this batch is:  0.04583345726132393
# the loss after processing this batch is:  0.020621538162231445
# the loss after processing this batch is:  0.016662387177348137
# the loss after processing this batch is:  0.024602865800261497
# the loss after processing this batch is:  0.08893497288227081
# the loss after processing this batch is:  0.15116623044013977
# the loss after processing this batch is:  0.06942571699619293
# the loss after processing this batch is:  0.050263501703739166
# the loss after processing this batch is:  0.06643655896186829
# the loss after processing this batch is:  0.043644025921821594
# the loss after processing this batch is:  0.03873351961374283
# the loss after processing this batch is:  0.06570939719676971
# the loss after processing this batch is:  0.0383031964302063
# the loss after processing this batch is:  0.0555558018386364
# the loss after processing this batch is:  0.06153618544340134
# the loss after processing this batch is:  0.06310566514730453
# the loss after processing this batch is:  0.05621493607759476
# the loss after processing this batch is:  0.07847324013710022
# the loss after processing this batch is:  0.05685160681605339
# the loss after processing this batch is:  0.06228425353765488
# the loss after processing this batch is:  0.0677715465426445
# the loss after processing this batch is:  0.04801477491855621
# the loss after processing this batch is:  0.06575995683670044
# the loss after processing this batch is:  0.06889453530311584
# the loss after processing this batch is:  0.08269356191158295
# the loss after processing this batch is:  0.04914908856153488
# the loss after processing this batch is:  0.04149261489510536
# the loss after processing this batch is:  0.055098794400691986
# the loss after processing this batch is:  0.0412609726190567
# the loss after processing this batch is:  0.04716988652944565
# the loss after processing this batch is:  0.05664471909403801
# the loss after processing this batch is:  0.059125177562236786
# the loss after processing this batch is:  0.038409050554037094
# the loss after processing this batch is:  0.048271551728248596
# the loss after processing this batch is:  0.05877194181084633
# the loss after processing this batch is:  0.031964078545570374
# the loss after processing this batch is:  0.04654807597398758
# the loss after processing this batch is:  0.05462166294455528
# the loss after processing this batch is:  0.05255803093314171
# the loss after processing this batch is:  0.05406523123383522
# the loss after processing this batch is:  0.06629321724176407
# the loss after processing this batch is:  0.05011211335659027
# the loss after processing this batch is:  0.03144475817680359
# the loss after processing this batch is:  0.05054476484656334
# the loss after processing this batch is:  0.05322670564055443
# the loss after processing this batch is:  0.05408716946840286
# the loss after processing this batch is:  0.06991837918758392
# the loss after processing this batch is:  0.03013591840863228
# the loss after processing this batch is:  0.02012338675558567
# the loss after processing this batch is:  0.032516710460186005
# the loss after processing this batch is:  0.04732633754611015
# the loss after processing this batch is:  0.02966625988483429
# the loss after processing this batch is:  0.054321080446243286
# the loss after processing this batch is:  0.030306220054626465
# the loss after processing this batch is:  0.09142199158668518
# the loss after processing this batch is:  0.04919073358178139
# the loss after processing this batch is:  0.047216542065143585
# the loss after processing this batch is:  0.06893757730722427
# the loss after processing this batch is:  0.09177448600530624
# the loss after processing this batch is:  0.0627383142709732
# the loss after processing this batch is:  0.028264593333005905
# the loss after processing this batch is:  0.0613982267677784
# the loss after processing this batch is:  0.04987761378288269
# the loss after processing this batch is:  0.04031551629304886
# the loss after processing this batch is:  0.045420870184898376
# the loss after processing this batch is:  0.03377699851989746
# the loss after processing this batch is:  0.05543433502316475
# the loss after processing this batch is:  0.07753105461597443
# the loss after processing this batch is:  0.039576753973960876
# the loss after processing this batch is:  0.06956367194652557
# the loss after processing this batch is:  0.04488430917263031
# the loss after processing this batch is:  0.05565595254302025
# the loss after processing this batch is:  0.031061917543411255
# the loss after processing this batch is:  0.053765423595905304
# ...
# the loss after processing this batch is:  0.037397436797618866
# the loss after processing this batch is:  0.04572145640850067
# the loss after processing this batch is:  0.06060350686311722
# the loss after processing this batch is:  0.02996731735765934
# the loss after processing this batch is:  0.07106132805347443
# the loss after processing this batch is:  0.039623647928237915
# the loss after processing this batch is:  0.033828120678663254
# the loss after processing this batch is:  0.035727132111787796
# the loss after processing this batch is:  0.03354501351714134
# the loss after processing this batch is:  0.04153716564178467
# the loss after processing this batch is:  0.044421982020139694
# the loss after processing this batch is:  0.04613841697573662
# the loss after processing this batch is:  0.023527497425675392
# the loss after processing this batch is:  0.037107910960912704
# the loss after processing this batch is:  0.016275666654109955
# the loss after processing this batch is:  0.012451840564608574
# the loss after processing this batch is:  0.01563939079642296
# the loss after processing this batch is:  0.07354579120874405
# the loss after processing this batch is:  0.1334565132856369
# the loss after processing this batch is:  0.056065093725919724
# the loss after processing this batch is:  0.03999098017811775
# the loss after processing this batch is:  0.05690499022603035
# the loss after processing this batch is:  0.037171341478824615
# the loss after processing this batch is:  0.035391829907894135
# the loss after processing this batch is:  0.05667717009782791
# the loss after processing this batch is:  0.02917245402932167
# the loss after processing this batch is:  0.04246773570775986
# the loss after processing this batch is:  0.0473385788500309
# the loss after processing this batch is:  0.04694702476263046
# the loss after processing this batch is:  0.04581490531563759
# the loss after processing this batch is:  0.05671999603509903
# the loss after processing this batch is:  0.04801388829946518
# the loss after processing this batch is:  0.047226786613464355
# the loss after processing this batch is:  0.05497225746512413
# the loss after processing this batch is:  0.0398314967751503
# the loss after processing this batch is:  0.05212654173374176
# the loss after processing this batch is:  0.0542735829949379
# the loss after processing this batch is:  0.06826218962669373
# the loss after processing this batch is:  0.03865298256278038
# the loss after processing this batch is:  0.03426598384976387
# the loss after processing this batch is:  0.05041620507836342
# the loss after processing this batch is:  0.028771769255399704
# the loss after processing this batch is:  0.03802549093961716
# the loss after processing this batch is:  0.04187849909067154
# the loss after processing this batch is:  0.04621390998363495
# the loss after processing this batch is:  0.03166972100734711
# the loss after processing this batch is:  0.03901930898427963
# the loss after processing this batch is:  0.044252075254917145
# the loss after processing this batch is:  0.02619822695851326
# the loss after processing this batch is:  0.0369335412979126
# the loss after processing this batch is:  0.04380703344941139
# the loss after processing this batch is:  0.04014871269464493
# the loss after processing this batch is:  0.04520922154188156
# the loss after processing this batch is:  0.05043554678559303
# the loss after processing this batch is:  0.04024430736899376
# the loss after processing this batch is:  0.024153079837560654
# the loss after processing this batch is:  0.04185052216053009
# the loss after processing this batch is:  0.04252459108829498
# the loss after processing this batch is:  0.0391409657895565
# the loss after processing this batch is:  0.05701299011707306
# the loss after processing this batch is:  0.019414663314819336
# the loss after processing this batch is:  0.014509409666061401
# the loss after processing this batch is:  0.02568988688290119
# the loss after processing this batch is:  0.03632330894470215
# the loss after processing this batch is:  0.02285047434270382
# the loss after processing this batch is:  0.04470402002334595
# the loss after processing this batch is:  0.021613623946905136
# the loss after processing this batch is:  0.07802331447601318
# the loss after processing this batch is:  0.03940212354063988
# the loss after processing this batch is:  0.03785847872495651
# the loss after processing this batch is:  0.06213385611772537
# the loss after processing this batch is:  0.08120445162057877
# the loss after processing this batch is:  0.046736910939216614
# the loss after processing this batch is:  0.021117448806762695
# the loss after processing this batch is:  0.05185838043689728
# the loss after processing this batch is:  0.04090384393930435
# the loss after processing this batch is:  0.03272600471973419
# the loss after processing this batch is:  0.04108728840947151
# the loss after processing this batch is:  0.021941596642136574
# the loss after processing this batch is:  0.04280739277601242
# the loss after processing this batch is:  0.06376009434461594
# the loss after processing this batch is:  0.03211447224020958
# the loss after processing this batch is:  0.056230027228593826
# the loss after processing this batch is:  0.03655444085597992
# the loss after processing this batch is:  0.048229753971099854
# the loss after processing this batch is:  0.025640662759542465
# the loss after processing this batch is:  0.04083889722824097
# the loss after processing this batch is:  0.04782027751207352
# the loss after processing this batch is:  0.04245256632566452
# the loss after processing this batch is:  0.03179007023572922
# the loss after processing this batch is:  0.03879281133413315
# the loss after processing this batch is:  0.04229643940925598
# the loss after processing this batch is:  0.05001150816679001
# the loss after processing this batch is:  0.028791531920433044
# the loss after processing this batch is:  0.03374415636062622
# the loss after processing this batch is:  0.04754851758480072
# the loss after processing this batch is:  0.037587352097034454
# the loss after processing this batch is:  0.03914044052362442
# the loss after processing this batch is:  0.03571443259716034
# the loss after processing this batch is:  0.05328100919723511
# the loss after processing this batch is:  0.036070629954338074
# the loss after processing this batch is:  0.039459723979234695
# the loss after processing this batch is:  0.040434397757053375
# the loss after processing this batch is:  0.04023895412683487
# the loss after processing this batch is:  0.02992440201342106
# the loss after processing this batch is:  0.042415130883455276
# the loss after processing this batch is:  0.03325634077191353
# the loss after processing this batch is:  0.03534860908985138
# the loss after processing this batch is:  0.05684751272201538
# the loss after processing this batch is:  0.0521426685154438
# the loss after processing this batch is:  0.05378354713320732
# the loss after processing this batch is:  0.06167500838637352
# the loss after processing this batch is:  0.03200150653719902
# the loss after processing this batch is:  0.022156283259391785
# the loss after processing this batch is:  0.0647895485162735
# the loss after processing this batch is:  0.061728447675704956
# the loss after processing this batch is:  0.038895465433597565
# the loss after processing this batch is:  0.06651218235492706
# the loss after processing this batch is:  0.034105896949768066
# the loss after processing this batch is:  0.04321630671620369
# the loss after processing this batch is:  0.053903184831142426
# the loss after processing this batch is:  0.027174178510904312
# the loss after processing this batch is:  0.0626675933599472
# the loss after processing this batch is:  0.03817041963338852
# the loss after processing this batch is:  0.030059054493904114
# the loss after processing this batch is:  0.03157772868871689
# the loss after processing this batch is:  0.030292514711618423
# the loss after processing this batch is:  0.04031585156917572
# the loss after processing this batch is:  0.04259538650512695
# the loss after processing this batch is:  0.04188285768032074
# the loss after processing this batch is:  0.020763400942087173
# the loss after processing this batch is:  0.032562609761953354
# the loss after processing this batch is:  0.014242629520595074
# the loss after processing this batch is:  0.011196985840797424
# the loss after processing this batch is:  0.014634029939770699
# the loss after processing this batch is:  0.07077530026435852
# the loss after processing this batch is:  0.12251493334770203
# the loss after processing this batch is:  0.05355994403362274
# the loss after processing this batch is:  0.0359947606921196
# the loss after processing this batch is:  0.05365676060318947
# the loss after processing this batch is:  0.034483909606933594
# the loss after processing this batch is:  0.03338976949453354
# the loss after processing this batch is:  0.05171173810958862
# the loss after processing this batch is:  0.02554021030664444
# the loss after processing this batch is:  0.038544341921806335
# the loss after processing this batch is:  0.04290138930082321
# the loss after processing this batch is:  0.04142273962497711
# the loss after processing this batch is:  0.04232312738895416
# the loss after processing this batch is:  0.048312071710824966
# the loss after processing this batch is:  0.04228319972753525
# the loss after processing this batch is:  0.042719535529613495
# the loss after processing this batch is:  0.05128510668873787
# the loss after processing this batch is:  0.0376647487282753
# the loss after processing this batch is:  0.04412849247455597
# the loss after processing this batch is:  0.04891763627529144
# the loss after processing this batch is:  0.06278529018163681
# the loss after processing this batch is:  0.0351397842168808
# the loss after processing this batch is:  0.03311929106712341
# the loss after processing this batch is:  0.04831481724977493
# the loss after processing this batch is:  0.024927623569965363
# the loss after processing this batch is:  0.03517838567495346
# the loss after processing this batch is:  0.03590233996510506
# the loss after processing this batch is:  0.04047829285264015
# the loss after processing this batch is:  0.02878481149673462
# the loss after processing this batch is:  0.034956254065036774
# the loss after processing this batch is:  0.040436021983623505
# the loss after processing this batch is:  0.023813212290406227
# the loss after processing this batch is:  0.03348071500658989
# the loss after processing this batch is:  0.03892857953906059
# the loss after processing this batch is:  0.036412447690963745
# the loss after processing this batch is:  0.04224269464612007
# the loss after processing this batch is:  0.04465396702289581
# the loss after processing this batch is:  0.0370614156126976
# the loss after processing this batch is:  0.022199880331754684
# the loss after processing this batch is:  0.03913762420415878
# the loss after processing this batch is:  0.03759036958217621
# the loss after processing this batch is:  0.033051498234272
# the loss after processing this batch is:  0.052225511521101
# the loss after processing this batch is:  0.016918044537305832
# the loss after processing this batch is:  0.013732952065765858
# the loss after processing this batch is:  0.023452812805771828
# the loss after processing this batch is:  0.03304394334554672
# the loss after processing this batch is:  0.02112356200814247
# the loss after processing this batch is:  0.040918223559856415
# the loss after processing this batch is:  0.017732083797454834
# the loss after processing this batch is:  0.0708075761795044
# the loss after processing this batch is:  0.03558240458369255
# the loss after processing this batch is:  0.036017801612615585
# the loss after processing this batch is:  0.06062140315771103
# the loss after processing this batch is:  0.07777945697307587
# the loss after processing this batch is:  0.04087941348552704
# the loss after processing this batch is:  0.018508849665522575
# the loss after processing this batch is:  0.047952596098184586
# the loss after processing this batch is:  0.03802887722849846
# the loss after processing this batch is:  0.02881047874689102
# the loss after processing this batch is:  0.0384180024266243
# the loss after processing this batch is:  0.019451599568128586
# the loss after processing this batch is:  0.03789331763982773
# the loss after processing this batch is:  0.05631028860807419
# the loss after processing this batch is:  0.030051253736019135
# the loss after processing this batch is:  0.05076756328344345
# the loss after processing this batch is:  0.03293213993310928
# the loss after processing this batch is:  0.04472491890192032
# the loss after processing this batch is:  0.02276787720620632
# the loss after processing this batch is:  0.03662717714905739
# the loss after processing this batch is:  0.04390697926282883
# the loss after processing this batch is:  0.03909019008278847
# the loss after processing this batch is:  0.030543949455022812
# the loss after processing this batch is:  0.03719715029001236
# the loss after processing this batch is:  0.03887774795293808
# the loss after processing this batch is:  0.04694449156522751
# the loss after processing this batch is:  0.025507071986794472
# the loss after processing this batch is:  0.03323777765035629
# the loss after processing this batch is:  0.04419528692960739
# the loss after processing this batch is:  0.03618887811899185
# the loss after processing this batch is:  0.03757531940937042
# the loss after processing this batch is:  0.03263797610998154
# the loss after processing this batch is:  0.048796456307172775
# the loss after processing this batch is:  0.032333482056856155
# the loss after processing this batch is:  0.033092692494392395
# the loss after processing this batch is:  0.03657884523272514
# the loss after processing this batch is:  0.038963496685028076
# the loss after processing this batch is:  0.026838790625333786
# the loss after processing this batch is:  0.0390462800860405
# the loss after processing this batch is:  0.029782166704535484
# the loss after processing this batch is:  0.03333350270986557
# the loss after processing this batch is:  0.05214214697480202
# the loss after processing this batch is:  0.04775726795196533
# the loss after processing this batch is:  0.051255133002996445
# the loss after processing this batch is:  0.05810845270752907
# the loss after processing this batch is:  0.027871130034327507
# the loss after processing this batch is:  0.02006635069847107
# the loss after processing this batch is:  0.06007974594831467
# the loss after processing this batch is:  0.0578441396355629
# the loss after processing this batch is:  0.03598182648420334
# the loss after processing this batch is:  0.06186143681406975
# the loss after processing this batch is:  0.03209080174565315
# the loss after processing this batch is:  0.04119907319545746
# the loss after processing this batch is:  0.04805392399430275
# the loss after processing this batch is:  0.025772035121917725
# the loss after processing this batch is:  0.056312043219804764
# the loss after processing this batch is:  0.035360515117645264
# the loss after processing this batch is:  0.027663029730319977
# the loss after processing this batch is:  0.028678301721811295
# the loss after processing this batch is:  0.026560313999652863
# the loss after processing this batch is:  0.03746872395277023
# the loss after processing this batch is:  0.04007420688867569
# the loss after processing this batch is:  0.03832679241895676
# the loss after processing this batch is:  0.019249629229307175
# the loss after processing this batch is:  0.029084675014019012
# the loss after processing this batch is:  0.01317292544990778
# the loss after processing this batch is:  0.010427048429846764
# the loss after processing this batch is:  0.012819742783904076
# the loss after processing this batch is:  0.06828809529542923
# the loss after processing this batch is:  0.10996482521295547
# Training completed.
# =*==*==*==*==*==*==*==*==*==*==*==*==*==*==*==*==*==*==*==*=

# %%
def fgsm(model, X, y, epsilon):
    """ Construct FGSM adversarial examples on the examples X"""
    #delta = torch.zeros_like(X, requires_grad=True)
    #loss = nn.CrossEntropyLoss()(model(X + delta), y)
    X.requires_grad = True
    output = model(X)
    #output = F.log_softmax(output, dim=1)
    loss = F.nll_loss(output, y)

    loss.backward()
    #adv_noise = epsilon * delta.grad.detach().sign()
    adv_noise = epsilon * X.grad.detach().sign()
    return adv_noise

# %%
for X,y in test_loader:
    X,y = X.to(device), y.to(device)
    break
    
def plot_images(X,y,yp,M,N):
    f,ax = plt.subplots(M,N, sharex=True, sharey=True, figsize=(N,M*1.3))
    for i in range(M):
        for j in range(N):
            ax[i][j].imshow(1-X[i*N+j][0].detach().cpu().numpy(), cmap="gray")
            title = ax[i][j].set_title("Pred: {}".format(yp[i*N+j].max(dim=0)[1]))
            plt.setp(title, color=('g' if yp[i*N+j].max(dim=0)[1] == y[i*N+j] else 'r'))
            ax[i][j].set_axis_off()
    plt.tight_layout()

# %%
yp = trained_model(X)
plot_images(X, y, yp, 3, 6)

# %%
delta = fgsm(trained_model, X, y, 0.3)
perturbed = torch.clamp(X+delta, 0, 1)
yp = trained_model(perturbed)

plot_images(perturbed, y, yp, 3, 6)

# %%
def epoch_adversarial(model, loader, attack, *args):
    total_loss, total_err = 0.,0.
    for X,y in loader:
        X,y = X.to(device), y.to(device)
        delta = attack(model, X, y, *args)
        yp = model(X+delta)
        #yp = F.log_softmax(yp, dim=1)
        #loss = nn.CrossEntropyLoss()(yp,y)
        loss = F.nll_loss(yp, y)
        total_err += (yp.max(dim=1)[1] != y).sum().item()
        total_loss += loss.item() * X.shape[0]
    return 1-(total_err / len(loader.dataset)), total_loss / len(loader.dataset)

# %%
print("conv_net:", epoch_adversarial(trained_model, test_loader, fgsm, 0.3)[0])
# Out:
# conv_net: 0.07040000000000002

# %%
acc , examples =  test_attack(trained_model, device,test_loader, epsilon = 0.3)
# Out:
# Epsilon: 0.3	Test Accuracy = 1884 / 10000 = 0.1884

# %%
def pgd(model, X, y, epsilon, alpha, num_iter):
    """ Construct FGSM adversarial examples on the examples X"""
    delta = torch.zeros_like(X, requires_grad=True)
    for t in range(num_iter):
        loss = F.nll_loss(model(X + delta), y)
        loss.backward()
        delta.data = (delta + X.shape[0]*alpha*delta.grad.data).clamp(-epsilon,epsilon)
        delta.grad.zero_()
    return delta.detach()

# %%
delta = pgd(trained_model, X, y, 0.3, 1e4, 1000)
yp = trained_model(X + delta)
plot_images(X+delta, y, yp, 3, 6)

# %%
print("conv_net:", epoch_adversarial(trained_model, test_loader, pgd, 0.3, 1e4, 50)[0])
# Out:
# conv_net: 0.06430000000000002

# %%
def norms(Z):
    """Compute norms over all but the first dimension"""
    return Z.view(Z.shape[0], -1).norm(dim=1)[:,None,None,None]


def pgd_l2(model, X, y, epsilon, alpha, num_iter):
    delta = torch.zeros_like(X, requires_grad=True)
    for t in range(num_iter):
        loss = F.nll_loss(model(X + delta), y)
        loss.backward()
        delta.data += alpha*delta.grad.detach() / norms(delta.grad.detach())
        delta.data = torch.min(torch.max(delta.detach(), -X), 1-X) # clip X+delta to [0,1]
        delta.data *= epsilon / norms(delta.detach()).clamp(min=epsilon)
        delta.grad.zero_()
        
    return delta.detach()

# %%
delta = pgd_l2(trained_model, X, y, epsilon=2, alpha=0.3, num_iter=40)
yp = trained_model(X + delta)
plot_images(X+delta, y, yp, 3, 6)
print("CNN:", epoch_adversarial(trained_model, test_loader, pgd_l2, 2, 0.3, 40)[0])
# Out:
# CNN: 0.05620000000000003

# %%
def pgd_linf(model, X, y, epsilon, alpha, num_iter):
    """ Construct FGSM adversarial examples on the examples X"""
    delta = torch.zeros_like(X, requires_grad=True)
    for t in range(num_iter):
        loss = F.nll_loss(model(X + delta), y)
        loss.backward()
        delta.data = (delta + alpha*delta.grad.detach().sign()).clamp(-epsilon,epsilon)
        delta.grad.zero_()
    return delta.detach()

# %%
delta = pgd_linf(trained_model, X, y, epsilon=0.3, alpha=1e-2, num_iter=40)
yp = trained_model(X + delta)
plot_images(X+delta, y, yp, 3, 6)

# %%
print("CNN:", epoch_adversarial(trained_model, test_loader, pgd_linf, 0.3, 1e-2, 40)[0])
# Out:
# CNN: 0.0

# %%
fgsm.__name__ = "FGSM Attack"
pgd.__name__ = "Projected Gradient Attack"
pgd_l2.__name__="Deep Fool Attack"
pgd_linf.__name__="iFGSM Attack"

# %%
def attack(model, device, loader, attack_method, epsilon,*args ):

    print(attack_method.__name__+" : ")
    
    model.to(device)
    
    correct = 0
    total_loss = 0
    
    for batch in loader:
        
        batch_images, batch_labels = batch
        
        batch_images = batch_images.to(device)
        batch_labels = batch_labels.to(device)
        
        delta = attack_method(model, batch_images, batch_labels, epsilon, *args)
        predictions = model(batch_images+delta)

        loss = F.nll_loss(predictions, batch_labels)
        correct += (predictions.max(dim=1)[1] == batch_labels).sum().item()
        total_loss += loss.item() * batch_images.shape[0]
        
    accuracy = correct / len(loader.dataset)
    loss = total_loss / len(loader.dataset)
    
    return accuracy, loss 
        
    pass

# %%
def get_adv_examples(model, device, loader, attack_method, epsilon,*args ):
    
    adv_examples = []
    
    model.to(device)
    
    for batch in loader:
        
        batch_images, batch_labels = batch
        
        batch_images = batch_images.to(device)
        batch_labels = batch_labels.to(device)
        
        deltas = attack_method(model, batch_images, batch_labels, epsilon, *args)
        
        adv_images = torch.clamp(batch_images+deltas, 0, 1)
        
        adv_examples.append((batch_images, adv_images, batch_labels))
    
    return adv_examples

# %%
print(attack(trained_model, device, test_loader, fgsm, 0.3)[0])
print("=*"*20)
# Out:
# fgsm :
# 0.0773
# =*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*

# %%
print(attack(trained_model, device, test_loader, pgd, 0.3, 1e-2, 40)[0])
print("=*"*20)
# Out:
# Projected Gradient Attack :
# 0.0583
# =*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*

# %%
print(attack(trained_model, device, test_loader, pgd_linf, 0.1, 1e-3, 40)[0])
print("=*"*20)
# Out:
# iFGSM Attack :
# 0.6522
# =*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*

# %%
print(attack(trained_model, device, test_loader, pgd_l2, 2, 0.3, 40)[0])
# Out:
# Deep Fool Attack :
# 0.0563

# %%
train_data = get_adv_examples(trained_model, device, test_loader, fgsm, 0.3)
# Out:
# fgsm :

# %%
print(len(train_data))

train_iter = iter(train_data)
a, b, c = next(train_iter)

show_batch(a.cpu())
show_batch(b.cpu())
print(c)
# Out:
# 20
# tensor([7, 2, 1, 0, 4, 1, 4, 9, 5, 9, 0, 6, 9, 0, 1, 5, 9, 7, 3, 4, 9, 6, 6, 5,
#         4, 0, 7, 4, 0, 1, 3, 1, 3, 4, 7, 2, 7, 1, 2, 1, 1, 7, 4, 2, 3, 5, 1, 2,
#         4, 4, 6, 3, 5, 5, 6, 0, 4, 1, 9, 5, 7, 8, 9, 3, 7, 4, 6, 4, 3, 0, 7, 0,
#         2, 9, 1, 7, 3, 2, 9, 7, 7, 6, 2, 7, 8, 4, 7, 3, 6, 1, 3, 6, 9, 3, 1, 4,
#         1, 7, 6, 9, 6, 0, 5, 4, 9, 9, 2, 1, 9, 4, 8, 7, 3, 9, 7, 4, 4, 4, 9, 2,
#         5, 4, 7, 6, 7, 9, 0, 5, 8, 5, 6, 6, 5, 7, 8, 1, 0, 1, 6, 4, 6, 7, 3, 1,
#         7, 1, 8, 2, 0, 2, 9, 9, 5, 5, 1, 5, 6, 0, 3, 4, 4, 6, 5, 4, 6, 5, 4, 5,
#         1, 4, 4, 7, 2, 3, 2, 7, 1, 8, 1, 8, 1, 8, 5, 0, 8, 9, 2, 5, 0, 1, 1, 1,
#         0, 9, 0, 3, 1, 6, 4, 2, 3, 6, 1, 1, 1, 3, 9, 5, 2, 9, 4, 5, 9, 3, 9, 0,
#         3, 6, 5, 5, 7, 2, 2, 7, 1, 2, 8, 4, 1, 7, 3, 3, 8, 8, 7, 9, 2, 2, 4, 1,
#         5, 9, 8, 7, 2, 3, 0, 4, 4, 2, 4, 1, 9, 5, 7, 7, 2, 8, 2, 6, 8, 5, 7, 7,
#         9, 1, 8, 1, 8, 0, 3, 0, 1, 9, 9, 4, 1, 8, 2, 1, 2, 9, 7, 5, 9, 2, 6, 4,
#         1, 5, 8, 2, 9, 2, 0, 4, 0, 0, 2, 8, 4, 7, 1, 2, 4, 0, 2, 7, 4, 3, 3, 0,
#         0, 3, 1, 9, 6, 5, 2, 5, 9, 2, 9, 3, 0, 4, 2, 0, 7, 1, 1, 2, 1, 5, 3, 3,
#         9, 7, 8, 6, 5, 6, 1, 3, 8, 1, 0, 5, 1, 3, 1, 5, 5, 6, 1, 8, 5, 1, 7, 9,
#         4, 6, 2, 2, 5, 0, 6, 5, 6, 3, 7, 2, 0, 8, 8, 5, 4, 1, 1, 4, 0, 3, 3, 7,
#         6, 1, 6, 2, 1, 9, 2, 8, 6, 1, 9, 5, 2, 5, 4, 4, 2, 8, 3, 8, 2, 4, 5, 0,
#         3, 1, 7, 7, 5, 7, 9, 7, 1, 9, 2, 1, 4, 2, 9, 2, 0, 4, 9, 1, 4, 8, 1, 8,
#         4, 5, 9, 8, 8, 3, 7, 6, 0, 0, 3, 0, 2, 6, 6, 4, 9, 3, 3, 3, 2, 3, 9, 1,
#         2, 6, 8, 0, 5, 6, 6, 6, 3, 8, 8, 2, 7, 5, 8, 9, 6, 1, 8, 4, 1, 2, 5, 9,
#         1, 9, 7, 5, 4, 0, 8, 9, 9, 1, 0, 5, 2, 3, 7, 8, 9, 4, 0, 6, 3, 9, 5, 2,
#         1, 3, 1, 3, 6, 5, 7, 4], device='cuda:0')
